# %% [markdown]
# # Title: Data Capture tool  for Collecting Attendance and Breach data of Type 1 Hospitals
# **Author details:** B199291. *Contact details:* .
# **Notebook and data info:** This Notebook provides a web form to collect the NHS England accident and emergency attendances and admissions (ae_attendances) in the Type 1 A&E Departments and save it to my 'RefData’ folder.
# **Data:** Data consists of date, numerical data and character data.
# **Copyright statement:** This Notebook is the product of The University of Edinburgh.
#
# # Data
# The data I will be managing on this project are from the NHSRdatasets package.The dataset I have chosen to manage from the NHSRdatasets package is the NHS accident and emergency (A&E) attendances and admissions (`ae_attendances`) data. The `ae_attendances` data includes reported attendances, four-hour breaches and admissions for all A&E departments in UK for 2016/17 through 2018/19 (Apr-Mar). For the analysis of NHS UK to be able to monitor the benchmark of type 1 hospitals,I will use a subset of the variables  which are organization codes of type 1 emergency departments,recorded month, attendances and breaches, and subsetted the data into test and training data.

# %%
#Load the 'pandas' package to import data
import pandas as pd
testData=pd.read_csv("../WorkingData/ae_type1_test.csv")
testData
# Out:
#     Index      period org_code  type  attendances  breaches  admissions
# 0    2826  2016-07-01      RGT     1        10081      2288        3123
# 1    2865  2016-07-01      RM1     1        10303      1080        2891
# 2    3941  2016-04-01      RRK     1         9044      1195        2744
# 3    5431  2017-12-01      RJN     1         4238      1208         971
# 4    5940  2017-11-01      RNZ     1         3940       209        1131
# 5    6727  2017-08-01      RQ3     1         3801        86         754
# 6    7952  2017-05-01      RBL     1         8270      2120        2491
# 7    8427  2019-03-01      R1K     1        12753      3178        6522
# 8   10489  2018-10-01      RPA     1         7710      1750        2065
# 9   12390  2018-05-01      RA3     1         4390       348        1090
# 10  12463  2018-04-01      RDE     1         7942       523        2398

# %%
#checking the data type of the reference data frame so that we can collect right data type when we build data capture tool
result = testData.dtypes
print(result)
# Out:
# Index           int64
# period         object
# org_code       object
# type            int64
# attendances     int64
# breaches        int64
# admissions      int64
# dtype: object

# %%
#looking columan names to map data collection tool
testData.head(n=1)
# Out:
#    Index      period org_code  type  attendances  breaches  admissions
# 0   2826  2016-07-01      RGT     1        10081      2288        3123

# %% [markdown]
# We need to set up an empty data frame including consent information in the working data folder to collect the data captured by the Juypter widgets.

# %%
dfTofill = pd.DataFrame({'index': [0],# Integer
                   'period': [pd.Timestamp('20000101')], # Date
                   'org_code': ['NA'], # String
                   'attendances': [0], # Integer
                   'breaches': [0], # Integer
                   'consent': [False]}) # Boolean 

dfTofill
# Out:
#    index     period org_code  attendances  breaches  consent
# 0      0 2000-01-01       NA            0         0    False

# %% [markdown]
# Save the empty data frame to my 'WorkingData' folder and will comment out to prevent duplication

# %%
#dfTofill.to_csv('../WorkingData/CollectedData.csv', index=False)

# %%
CollectData=pd.read_csv("../WorkingData/CollectedData.csv")
CollectData
# Out:
#     index      period org_code  attendances  breaches  consent
# 0    2826  2016-07-01      RGT        10081      2288     True
# 1    2865  2016-07-01      RM1        10303      1080     True
# 2    3941  2016-04-01      RRK         9044      1195     True
# 3    5431  2017-12-01      RJN         4238      1208     True
# 4    5940  2017-11-01      RNZ         3940       209     True
# 5    6727  2017-08-01      RQ3         3801        86     True
# 6    7952  2017-05-01      RBL         8270      2120     True
# 7    8427  2019-03-01      R1K        12753      3178     True
# 8   10489  2018-10-01      RPA         7710      1750     True
# 9   12390  2018-05-01      RA3         4390       348     True
# 10  12463  2018-04-01      RDE         7942       523     True

# %%
testData.head(n=11)
# Out:
#     Index      period org_code  type  attendances  breaches  admissions
# 0    2826  2016-07-01      RGT     1        10081      2288        3123
# 1    2865  2016-07-01      RM1     1        10303      1080        2891
# 2    3941  2016-04-01      RRK     1         9044      1195        2744
# 3    5431  2017-12-01      RJN     1         4238      1208         971
# 4    5940  2017-11-01      RNZ     1         3940       209        1131
# 5    6727  2017-08-01      RQ3     1         3801        86         754
# 6    7952  2017-05-01      RBL     1         8270      2120        2491
# 7    8427  2019-03-01      R1K     1        12753      3178        6522
# 8   10489  2018-10-01      RPA     1         7710      1750        2065
# 9   12390  2018-05-01      RA3     1         4390       348        1090
# 10  12463  2018-04-01      RDE     1         7942       523        2398

# %% [markdown]
# # Indexing to connect with original ae_type1.csv data

# %%
index_number=12463
dfTofill.iloc[0,0]=index_number
dfTofill
# Out:
#    index     period org_code  attendances  breaches  consent
# 0  12463 2000-01-01       NA            0         0    False

# %%
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# ## Consent Form using Checkbox widget

# %%
a = widgets.Checkbox(
    value=False,
    description='I consent for the data I have provided to be processed and shared in accordance with data protection regulations with the purpose of improving care service provision across the UK.',
    disabled=False
)

# %%
display(a)
# Out:
# Checkbox(value=False, description='I consent for the data I have provided to be processed and shared in accord…

# %%
#linking with dftofill dataset 
dfTofill.iloc[0,5]=a.value
dfTofill
# Out:
#    index     period org_code  attendances  breaches  consent
# 0  12463 2000-01-01       NA            0         0    False

# %% [markdown]
# # Creating widget to collect Date

# %%
print(result[1])
#checking datatypes of period and it is string
# Out:
# object

# %%
testData.head(n=11)
# Out:
#     Index      period org_code  type  attendances  breaches  admissions
# 0    2826  2016-07-01      RGT     1        10081      2288        3123
# 1    2865  2016-07-01      RM1     1        10303      1080        2891
# 2    3941  2016-04-01      RRK     1         9044      1195        2744
# 3    5431  2017-12-01      RJN     1         4238      1208         971
# 4    5940  2017-11-01      RNZ     1         3940       209        1131
# 5    6727  2017-08-01      RQ3     1         3801        86         754
# 6    7952  2017-05-01      RBL     1         8270      2120        2491
# 7    8427  2019-03-01      R1K     1        12753      3178        6522
# 8   10489  2018-10-01      RPA     1         7710      1750        2065
# 9   12390  2018-05-01      RA3     1         4390       348        1090
# 10  12463  2018-04-01      RDE     1         7942       523        2398

# %%
b = widgets.DatePicker(
    description='Period',
    disabled=False
)
display(b)
# Out:
# DatePicker(value=None, description='Period')

# %%
dfTofill.iloc[0,1]=b.value
dfTofill
# Out:
#    index period org_code  attendances  breaches  consent
# 0  12463    NaT       NA            0         0    False

# %% [markdown]
# ## Creating widget to collect org_code of Type 1 Hospitals

# %%
print(result[2])
#checking data type and it is string
# Out:
# object

# %%
import numpy as np
testData.describe(include='all')
# Out:
#                Index      period org_code  type   attendances     breaches  \
# count      11.000000          11       11  11.0     11.000000    11.000000
# unique           NaN          10       11   NaN           NaN          NaN
# top              NaN  2016-07-01      RGT   NaN           NaN          NaN
# freq             NaN           2        1   NaN           NaN          NaN
# mean     7222.818182         NaN      NaN   1.0   7497.454545  1271.363636
# std      3478.562456         NaN      NaN   0.0   3033.109835   980.352311
# min      2826.000000         NaN      NaN   1.0   3801.000000    86.000000
# 25%      4686.000000         NaN      NaN   1.0   4314.000000   435.500000
# 50%      6727.000000         NaN      NaN   1.0   7942.000000  1195.000000
# 75%      9458.000000         NaN      NaN   1.0   9562.500000  1935.000000
# max     12463.000000         NaN      NaN   1.0  12753.000000  3178.000000
#
#          admissions
# count     11.000000
# unique          NaN
# ...

# %%
org_code=list(testData['org_code'].unique())
org_code
# Out:
# ['RGT', 'RM1', 'RRK', 'RJN', 'RNZ', 'RQ3', 'RBL', 'R1K', 'RPA', 'RA3', 'RDE']

# %%
testData.head(n=11)
# Out:
#     Index      period org_code  type  attendances  breaches  admissions
# 0    2826  2016-07-01      RGT     1        10081      2288        3123
# 1    2865  2016-07-01      RM1     1        10303      1080        2891
# 2    3941  2016-04-01      RRK     1         9044      1195        2744
# 3    5431  2017-12-01      RJN     1         4238      1208         971
# 4    5940  2017-11-01      RNZ     1         3940       209        1131
# 5    6727  2017-08-01      RQ3     1         3801        86         754
# 6    7952  2017-05-01      RBL     1         8270      2120        2491
# 7    8427  2019-03-01      R1K     1        12753      3178        6522
# 8   10489  2018-10-01      RPA     1         7710      1750        2065
# 9   12390  2018-05-01      RA3     1         4390       348        1090
# 10  12463  2018-04-01      RDE     1         7942       523        2398

# %%
c=widgets.Select(
    options=org_code,
    value='RGT',
    rows=len(org_code),
    description='ODS code:',
    disabled=False
)
display(c)
# Out:
# Select(description='ODS code:', options=('RGT', 'RM1', 'RRK', 'RJN', 'RNZ', 'RQ3', 'RBL', 'R1K', 'RPA', 'RA3',…

# %%
dfTofill.iloc[0,2]=c.value
dfTofill
# Out:
#    index period org_code  attendances  breaches  consent
# 0  12463    NaT      RGT            0         0    False

# %% [markdown]
# # Creating widget to collect attendance variable

# %%
print(result[4])
# Out:
# int64

# %%
testData.head(n=11)
# Out:
#     Index      period org_code  type  attendances  breaches  admissions
# 0    2826  2016-07-01      RGT     1        10081      2288        3123
# 1    2865  2016-07-01      RM1     1        10303      1080        2891
# 2    3941  2016-04-01      RRK     1         9044      1195        2744
# 3    5431  2017-12-01      RJN     1         4238      1208         971
# 4    5940  2017-11-01      RNZ     1         3940       209        1131
# 5    6727  2017-08-01      RQ3     1         3801        86         754
# 6    7952  2017-05-01      RBL     1         8270      2120        2491
# 7    8427  2019-03-01      R1K     1        12753      3178        6522
# 8   10489  2018-10-01      RPA     1         7710      1750        2065
# 9   12390  2018-05-01      RA3     1         4390       348        1090
# 10  12463  2018-04-01      RDE     1         7942       523        2398

# %%
d=widgets.IntText(
    value=0,
    description='Attendances:',
    disabled=False)
display(d)
# Out:
# IntText(value=0, description='Attendances:')

# %%
dfTofill.iloc[0,3]=d.value
dfTofill
# Out:
#    index period org_code  attendances  breaches  consent
# 0  12463    NaT      RGT            0         0    False

# %% [markdown]
# # Creating widget to collect breaches variable

# %%
print(result[5])
# Out:
# int64

# %%
testData.head(11)
# Out:
#     Index      period org_code  type  attendances  breaches  admissions
# 0    2826  2016-07-01      RGT     1        10081      2288        3123
# 1    2865  2016-07-01      RM1     1        10303      1080        2891
# 2    3941  2016-04-01      RRK     1         9044      1195        2744
# 3    5431  2017-12-01      RJN     1         4238      1208         971
# 4    5940  2017-11-01      RNZ     1         3940       209        1131
# 5    6727  2017-08-01      RQ3     1         3801        86         754
# 6    7952  2017-05-01      RBL     1         8270      2120        2491
# 7    8427  2019-03-01      R1K     1        12753      3178        6522
# 8   10489  2018-10-01      RPA     1         7710      1750        2065
# 9   12390  2018-05-01      RA3     1         4390       348        1090
# 10  12463  2018-04-01      RDE     1         7942       523        2398

# %%
e=widgets.IntText(
    value=0,
    description='Breaches:',
    disabled=False)
display(e)
# Out:
# IntText(value=0, description='Breaches:')

# %%
dfTofill.iloc[0,4]=e.value
dfTofill
# Out:
#    index period org_code  attendances  breaches  consent
# 0  12463    NaT      RGT            0         0    False

# %% [markdown]
# # Concatenating the collected data to the CollectData data frame.
# Let us use the `concat()` function from the Python *pandas* package to append the CollectData and dfTofill data frames. The concat() function is used to concatenate *pandas* objects.

# %%
CollectData  = pd.concat([CollectData, dfTofill])
display(CollectData)
# Out:
#     index      period org_code  attendances  breaches  consent
# 0    2826  2016-07-01      RGT        10081      2288     True
# 1    2865  2016-07-01      RM1        10303      1080     True
# 2    3941  2016-04-01      RRK         9044      1195     True
# 3    5431  2017-12-01      RJN         4238      1208     True
# 4    5940  2017-11-01      RNZ         3940       209     True
# 5    6727  2017-08-01      RQ3         3801        86     True
# 6    7952  2017-05-01      RBL         8270      2120     True
# 7    8427  2019-03-01      R1K        12753      3178     True
# 8   10489  2018-10-01      RPA         7710      1750     True
# 9   12390  2018-05-01      RA3         4390       348     True
# 10  12463  2018-04-01      RDE         7942       523     True
# 0   12463         NaN      RGT            0         0    False

# %% [markdown]
# ## Making sure consent is given before saving the data

# %%
CollectData=CollectData[CollectData['consent'] == True]
display(CollectData)
# Out:
#     index      period org_code  attendances  breaches  consent
# 0    2826  2016-07-01      RGT        10081      2288     True
# 1    2865  2016-07-01      RM1        10303      1080     True
# 2    3941  2016-04-01      RRK         9044      1195     True
# 3    5431  2017-12-01      RJN         4238      1208     True
# 4    5940  2017-11-01      RNZ         3940       209     True
# 5    6727  2017-08-01      RQ3         3801        86     True
# 6    7952  2017-05-01      RBL         8270      2120     True
# 7    8427  2019-03-01      R1K        12753      3178     True
# 8   10489  2018-10-01      RPA         7710      1750     True
# 9   12390  2018-05-01      RA3         4390       348     True
# 10  12463  2018-04-01      RDE         7942       523     True

# %% [markdown]
# ### Saving the CollectData data frame

# %%
CollectData.to_csv('../RefData/CollectedData_final.csv', index=False)

# %% [markdown]
# That is the CollectData data frame saved to the working 'Data' folder. You need to iterate through this Notebook until you have collected all of your test data and then save the captured test data to your 'RawData' folder.

# %%
form=widgets.VBox([a,b,c,d,e])

# %%
display(form)
